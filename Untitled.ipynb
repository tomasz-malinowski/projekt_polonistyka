# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_1.csv')

# %%
df
# Out:
#            id                                              title  magazine_nr
# 0     39703.0                             Czy kobiety są towarem        10412  \
# 1     20805.0                                  Graliśmy u siebie        10237
# 2     25437.0                                    Surmy dla Surmy        10279
# 3     22169.0                Barometr cen: Mieszkania na wynajem        10249
# 4     37960.0  Dwa różne sposoby obrony  w razie nałożenia gr...        10395
# ..        ...                                                ...          ...
# 650  213409.0                   Zmiana strategii wobec uchodźców        12419
# 651  123414.0  Zmiany klimatyczne to prawdziwe  wyzwanie dla ...        11235
# 652  122119.0                    Zmiany powstrzymamy tylko razem        11221
# 653  123324.0                     Zwycięstwa  i słabości 2018 r.        11234
# 654  122120.0                             Życie to sztuka wyboru        11221
#
# ...

# %%
df2 = pd.read_csv('rzepa_tagged.csv')

# %%
df2
# Out:
#      Unnamed: 0   id                                              title
# 0             0   22              A może by Ostrołękę przestawić na gaz  \
# 1             1  148                    A więc rozejm, czyli Biden i Xi
# 2             2  180          Administracji z biznesem ma być po drodze
# 3             3    4          Amerykanie ratują porozumienie o klimacie
# 4             4   60               Amerykańska ropa może ruszyć w świat
# ..          ...  ...                                                ...
# 329         329  324                   Zmiana strategii wobec uchodźców
# 330         330  139  Zmiany klimatyczne to prawdziwe  wyzwanie dla ...
# 331         331   20                    Zmiany powstrzymamy tylko razem
# 332         332  105                     Zwycięstwa  i słabości 2018 r.
# 333         333   79                             Życie to sztuka wyboru
#
#      magazine_nr          source                            author
# ...
